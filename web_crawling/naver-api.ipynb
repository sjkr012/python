# %%
# 네이버 Developers 오픈 API 호출 예제 - python 버전을 참고하였습니다
# https://developers.naver.com/docs/search/blog/
# 문제 시 바로 삭제하겠습니다

# 뉴스 open API 사용법
import os
import sys
import urllib.request  
import json
client_id = "YOUR_CLIENT_ID"  #YOUR_CLIENT_ID
client_secret = "YOUR_CLIENT_SECRET" #YOUR_CLIENT_SECRET
encText = urllib.parse.quote("물병") # 검색할 단어
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText # json 결과

# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    data = json.loads(response_body)
    #print(data['items'][0]['title'])
    #print(data['items'][0]['description'])
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 24 Jul 2020 17:31:46 +0900",
# "total": 109811,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "외출이 즐거워지는 칼 오스카, 스텐빨대<b>물병</b> 출시",
# "originallink": "http://www.globaledunews.co.kr/view.php?ud=2020072415154783726cf2d78c68_29",
# "link": "http://www.globaledunews.co.kr/view.php?ud=2020072415154783726cf2d78c68_29",
# "description": "스타일리쉬 하고 미니멀한 디자인과 러블리한 색상이 특징인 스웨덴 브랜드 칼 오스카(Carl Oscar)에서 스텐빨대<b>물병</b>을 출시했다. 칼 오스카 스텐빨대<b>물병</b>은 진공 단열재가 있는 2중벽 설계로 보냉보온 기능이 뛰어나... ",
# "pubDate": "Fri, 24 Jul 2020 15:17:00 +0900"
#
# },
# {
# "title": "겟잇뷰티2020, 황승언의 '브이라인 메이커' 비결은?",
# "originallink": "http://www.mrepublic.co.kr/news/articleView.html?idxno=50723",
# "link": "http://www.mrepublic.co.kr/news/articleView.html?idxno=50723",
# "description": "여러 루틴 중 그녀가 V라인 관리를 위해 마시는 '기분전환 브리라인티'는 &quot;스케줄 전날 밤 2L <b>물병</b>에 티백을 넣어 보관해 다음날 아침부터 스케줄 이동 시 마시고 있다&quot;고 전했다. 황승언이 자주 애용하는 생활약속의... ",
# "pubDate": "Fri, 24 Jul 2020 14:20:00 +0900"
#
# },
# {
# "title": "[★별자리운세] 2020년7월25일 (토요일) 동서양 별자리 타로운세",
# "originallink": "http://www.joongdo.co.kr/web/view.php?key=20200724010005273",
# "link": "http://www.joongdo.co.kr/web/view.php?key=20200724010005273",
# "description": "*금전운★ ★<b>물병</b>자리 [1.20~2.18] [LOVE] 서로의 상상만으로 오해를 하고 다투게 되니, 직접 보고 듣고, 말한 것 외에는 서로 믿고 의심하지마라. [JOB] 조용히 자신의 업무에만 집중한다면 별 일없이 지나가게 될 것이다.... ",
# "pubDate": "Fri, 24 Jul 2020 14:00:00 +0900"
#
# },
# {
# "title": "횡성군, 소상공인 일반음식점 스테인리스 <b>물병</b> 지원",
# "originallink": "http://www.kukinews.com/newsView/kuk202007240196",
# "link": "http://www.kukinews.com/newsView/kuk202007240196",
# "description": "강원 횡성군은 소상공인 일반음식점 775개소를 선정해 음식점에서 소독 가능한 위생물품(스테인리스<b>물병</b>) 총... 지원기준은 영업신고 면적에 따라 업소 당 5개~15개까지 차등 지급되며 소독 가능한 스테인리스<b>물병</b>으로... ",
# "pubDate": "Fri, 24 Jul 2020 13:20:00 +0900"
#
# },
# {
# "title": "마운틴, 로드, 하이브리드…내게 맞는 자전거는?",
# "originallink": "http://www.koreadaily.com/news/read.asp?art_id=8502245",
# "link": "http://www.koreadaily.com/news/read.asp?art_id=8502245",
# "description": "cannondale.com ■액서서리 및 구매 요령 필수 액서서리로는 헬멧과 바이크 펌프, 자전거 잠금장치, LED 안전등 등이 있으며 옵션으로 자전거 전용 슈즈, <b>물병</b> 홀더, 펑크 수리 도구, 바구니 등이 있다. 자동차와 마찬가지로... ",
# "pubDate": "Fri, 24 Jul 2020 13:18:00 +0900"
#
# },
# {
# "title": "횡성군, 소상공인 일반음식점 스테인리스 <b>물병</b> 지원",
# "originallink": "http://www.upkorea.net/news/articleView.html?idxno=765505",
# "link": "http://www.upkorea.net/news/articleView.html?idxno=765505",
# "description": "업코리아, UPKOREA ▲ 횡성군, 소상공인 일반음식점 스테인리스 <b>물병</b> 지원 [업코리아] 횡성군은 소상공인... 지원기준은 영업신고 면적에 따라 업소 당 5개~15개까지 차등 지급되며 소독 가능한 스테인리스<b>물병</b>으로... ",
# "pubDate": "Fri, 24 Jul 2020 11:30:00 +0900"
#
# },
# {
# "title": "월성원전 맥스터 증설, 경주시민 81.4% 찬성",
# "originallink": "http://www.newsis.com/view/?id=NISX20200724_0001106664&cID=10810&pID=10800",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=003&aid=0009985316",
# "description": "시민단체 등은 김 위원장이 밖으로 나오자 격렬히 반발하며 차량에 탑승하지 못하게 막고 <b>물병</b>에 든 물을 뿌리며 ‘사퇴하라’며 목소리를 높였다. ☞공감언론 뉴시스",
# "pubDate": "Fri, 24 Jul 2020 11:24:00 +0900"
#
# },
# {
# "title": "[창원 용호동 맛집] '딜리스' 정보승 대표, &quot;남녀노소 즐기고 맛 보실 수 있는...",
# "originallink": "http://www.upkorea.net/news/articleView.html?idxno=765107",
# "link": "http://www.upkorea.net/news/articleView.html?idxno=765107",
# "description": "가게외관 내부 접시 그릇 <b>물병</b> 화장실 모든것 하나하나 너무 신경많이 쓴 게 느껴진다면서 칭찬을 아끼지않으셨습니다 그동안 인테리어 컨셉과 디자인을 밤새며 직접다 하면서 고생했었던 시간이 떠오르며 너무... ",
# "pubDate": "Fri, 24 Jul 2020 11:12:00 +0900"
#
# },
# {
# "title": "횡성군, 소상공인 일반음식점 스테인리스 <b>물병</b> 지원",
# "originallink": "http://www.newstown.co.kr/news/articleView.html?idxno=463623",
# "link": "http://www.newstown.co.kr/news/articleView.html?idxno=463623",
# "description": "횡성군은 소상공인 일반음식점 775개소를 선정하여 음식점에서 소독 가능한 위생물품(스테인리스<b>물병</b>) 총 6... 지원기준은 영업신고 면적에 따라 업소 당 5개~15개까지 차등 지급되며 소독 가능한 스테인리스<b>물병</b>으로... ",
# "pubDate": "Fri, 24 Jul 2020 11:06:00 +0900"
#
# },
# {
# "title": "[금요일 별자리 운세] 보란 듯이 해피엔딩",
# "originallink": "http://www.econovill.com/news/articleView.html?idxno=405759",
# "link": "http://www.econovill.com/news/articleView.html?idxno=405759",
# "description": "<b>물병</b>자리 : 정신 차려, 정신 차려… 사람 사이의 문제 때문에 조금 고민을 하게 되는 날입니다. 게다가 판단력도 떨어지고 건망증까지 앓게 되니 정신이 없네요. 이럴 때일수록 정신을 차리기 위해서 노력을 해야 손실을... ",
# "pubDate": "Fri, 24 Jul 2020 09:20:00 +0900"
#
# }
# ]
# }
